# %% [markdown]
# ### Required
# Once you have selected a data set, you will produce the deliverables listed below and submit them to one of your peers for review. Treat this exercise as an opportunity to produce analysis that are ready to highlight your analytical skills for a senior audience, for example, the Chief Data Officer, or the Head of Analytics at your company.
#
# Sections required in your report:
#
# * Main objective of the analysis that also specifies whether your model will be focused on a specific type of Deep Learning or Reinforcement Learning algorithm and the benefits that your analysis brings to the business or stakeholders of this data.
#
# * Brief description of the data set you chose, a summary of its attributes, and an outline of what you are trying to accomplish with this analysis.
#
# * Brief summary of data exploration and actions taken for data cleaning or feature engineering.
#
# * Summary of training at least three variations of the Deep Learning model you selected. For example, you can use different clustering techniques or different hyperparameters.
#
# * A paragraph explaining which of your Deep Learning models you recommend as a final model that best fits your needs in terms of accuracy or explainability.
#
# * Summary Key Findings and Insights, which walks your reader through the main findings of your modeling exercise.
#
# * Suggestions for next steps in analyzing this data, which may include suggesting revisiting this model or adding specific data features to achieve a better model.

# %% [markdown]
# ### Main Objective:
# * This report will focus on the use of RNN and its variations to generate text from a Metallica tracklist dataset and deliver text of a similar style.
#
# * The main benefit is to generate interest in the use of neural networks for different aspects that are not necessarily commercial.

# %%
# import libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, SimpleRNN, GRU
from tensorflow.keras.optimizers import RMSprop
import numpy as np
import random
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### About the data
# * the data was collected directly from the official metallica website where there was an ordered list of all the songs, it was only necessary to remove the header from the lists
# * I try to get the network to learn the songs sequentially and print possible next values

# %%
# load the csv with pandas
link = "https://raw.githubusercontent.com/Vicente-Figueroa/Metallica_song_names/main/metallica.csv"
dataframe= pd.read_csv(link, sep='\t', names=['songs'])
input_names = dataframe['songs']
# print the head of the list
input_names[-5:]
# Out:
# 201                  Whiplash
# 202        Whiskey in the Jar
# 203    White Light/White Heat
# 204                    Would?
# 205         You Really Got Me
# Name: songs, dtype: object

# %% [markdown]
# ### Feature engineering
# * Since recurrent networks read data sequentially, we pass the songs as a sequence X and the next character as Y

# %%
# Make it all to a long string
concat_names = '\n'.join(input_names).lower()

# Find all unique characters by using set()
chars = sorted(list(set(concat_names)))
num_chars = len(chars)

# Build translation dictionaries, 'a' -> 0, 0 -> 'a'
char2idx = dict((c, i) for i, c in enumerate(chars))
idx2char = dict((i, c) for i, c in enumerate(chars))


# Use longest name length as our sequence window
max_sequence_length = max([len(name) for name in input_names])

print('Total chars: {}'.format(num_chars))
print('Corpus length:', len(concat_names))
print('Number of names: ', len(input_names))
print('Longest name: ', max_sequence_length)
# Out:
# Total chars: 43
# Corpus length: 3236
# Number of names:  206
# Longest name:  35

# %%
sequences = []
next_chars = []
step_length = 1


# Loop over our data and extract pairs of sequances and next chars
for i in range(0, len(concat_names) - max_sequence_length, step_length):
    sequences.append(concat_names[i: i + max_sequence_length])
    next_chars.append(concat_names[i + max_sequence_length])

num_sequences = len(sequences)

print('Number of sequences:', num_sequences)
print('First 10 sequences and next chars:')
for i in range(10):
    print('X=[{}] y=[{}]'.replace('\n', ' ').format(sequences[i], next_chars[i]).replace('\n', ' '))
# Out:
# Number of sequences: 3201
# First 10 sequences and next chars:
# X=[2 x 4 53rd & 3rd ain't my bitch all] y=[ ]
# X=[ x 4 53rd & 3rd ain't my bitch all ] y=[d]
# X=[x 4 53rd & 3rd ain't my bitch all d] y=[a]
# X=[ 4 53rd & 3rd ain't my bitch all da] y=[y]
# X=[4 53rd & 3rd ain't my bitch all day] y=[ ]
# X=[ 53rd & 3rd ain't my bitch all day ] y=[a]
# X=[53rd & 3rd ain't my bitch all day a] y=[n]
# X=[3rd & 3rd ain't my bitch all day an] y=[d]
# X=[rd & 3rd ain't my bitch all day and] y=[ ]
# X=[d & 3rd ain't my bitch all day and ] y=[a]

# %%
X = np.zeros((num_sequences, max_sequence_length, num_chars), dtype=np.bool)
Y = np.zeros((num_sequences, num_chars), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for j, char in enumerate(sequence):
        X[i, j, char2idx[char]] = 1
        Y[i, char2idx[next_chars[i]]] = 1

print('X shape: {}'.format(X.shape))
print('Y shape: {}'.format(Y.shape))
# Out:
# X shape: (3201, 35, 43)
# Y shape: (3201, 43)

# %% [markdown]
# ### Summary of training

# %%
# First we define the total of epochs and the amount of names generateds
epochs = 150
gen_amount = 10

# %%
# function to print generated names
def print_names(model, gen_amount):
    # Start sequence generation from end of the input sequence
    sequence = concat_names[-(max_sequence_length - 1):] + '\n'

    new_names = []
    print('{} new names are being generated'.format(gen_amount))

    while len(new_names) < gen_amount:
        # Vectorize sequence for prediction
        x = np.zeros((1, max_sequence_length, num_chars))
        for i, char in enumerate(sequence):
            x[0, i, char2idx[char]] = 1

        # Sample next char from predicted probabilities
        probs = model.predict(x, verbose=0)[0]
        probs /= probs.sum()
        next_idx = np.random.choice(len(probs), p=probs)
        next_char = idx2char[next_idx]
        sequence = sequence[1:] + next_char

        # New line means we have a new name
        if next_char == '\n':
            gen_name = [name for name in sequence.split('\n')][1]

            # Never start name with two identical chars, could probably also
            if len(gen_name) > 2 and gen_name[0] == gen_name[1]:
                gen_name = gen_name[1:]

            # Discard all names that are too short
            if len(gen_name) > 2:
                # Only allow new and unique names
                concat_list = np.concatenate((input_names, new_names), axis=0)
                if gen_name not in concat_list:
                    new_names.append(gen_name.capitalize())

            if 0 == (len(new_names) % (gen_amount/ 10)):
                print('Generated {}'.format(len(new_names)))
            
    return new_names

# %% [markdown]
# ### First model

# %%
latent_dim = 64 
dropout_rate = 0.2

# making the NN
model1 = Sequential()

# Add the LSTM layer 
model1.add(SimpleRNN(latent_dim,
               input_shape=(max_sequence_length, num_chars),
               recurrent_dropout=dropout_rate))

# Output layer dense and softmax activation
model1.add(Dense(units=num_chars, activation='softmax'))

# Optmizer in RMS
optimizer = RMSprop(lr=0.01)
model1.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                6912
#
#  dense (Dense)               (None, 43)                2795
#
# =================================================================
# Total params: 9,707
# Trainable params: 9,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32 

start = time.time()
print('Start training for {} epochs'.format(epochs))
history = model1.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose=1)
end = time.time()
print('Finished training - time elapsed:', (end - start)/60, 'min')
# Out:
# Start training for 150 epochs
# Epoch 1/150
# 101/101 [==============================] - 2s 7ms/step - loss: 3.1872
# Epoch 2/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9056
# Epoch 3/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9050
# Epoch 4/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9615
# Epoch 5/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9125
# Epoch 6/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8712
# Epoch 7/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.8771
# Epoch 8/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.8501
# Epoch 9/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8483
# Epoch 10/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8292
# Epoch 11/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.7821
# Epoch 12/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.7962
# Epoch 13/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8476
# Epoch 14/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.8842
# Epoch 15/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.8834
# Epoch 16/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8957
# Epoch 17/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9403
# Epoch 18/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9869
# Epoch 19/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9582
# Epoch 20/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9689
# Epoch 21/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9747
# Epoch 22/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9982
# Epoch 23/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0027
# Epoch 24/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9788
# Epoch 25/150
# 101/101 [==============================] - 1s 8ms/step - loss: 3.0128
# Epoch 26/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9981
# Epoch 27/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0221
# Epoch 28/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9969
# Epoch 29/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0346
# Epoch 30/150
# 101/101 [==============================] - 1s 8ms/step - loss: 3.0489
# Epoch 31/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0752
# Epoch 32/150
# 101/101 [==============================] - 1s 8ms/step - loss: 3.0733
# Epoch 33/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0676
# Epoch 34/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0547
# Epoch 35/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0547
# Epoch 36/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0675
# Epoch 37/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0422
# Epoch 38/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0468
# Epoch 39/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0786
# Epoch 40/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.1144
# Epoch 41/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.1097
# Epoch 42/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0702
# Epoch 43/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0651
# Epoch 44/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0869
# Epoch 45/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0746
# Epoch 46/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0972
# Epoch 47/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0727
# Epoch 48/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0827
# Epoch 49/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0841
# Epoch 50/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0355
# Epoch 51/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0188
# Epoch 52/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0402
# Epoch 53/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0265
# Epoch 54/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0542
# Epoch 55/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0629
# Epoch 56/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0524
# Epoch 57/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0640
# Epoch 58/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0392
# Epoch 59/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0576
# Epoch 60/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0133
# Epoch 61/150
# 101/101 [==============================] - 1s 8ms/step - loss: 3.0452
# Epoch 62/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0003
# Epoch 63/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9858
# Epoch 64/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.9901
# Epoch 65/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9901
# Epoch 66/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9551
# Epoch 67/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9729
# Epoch 68/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9594
# Epoch 69/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9731
# Epoch 70/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.9689
# Epoch 71/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9361
# Epoch 72/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9479
# Epoch 73/150
# 101/101 [==============================] - 1s 8ms/step - loss: 2.9455
# Epoch 74/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9606
# Epoch 75/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9530
# Epoch 76/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9683
# Epoch 77/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9936
# Epoch 78/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9591
# Epoch 79/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9536
# Epoch 80/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9681
# Epoch 81/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9285
# Epoch 82/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9023
# Epoch 83/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8857
# Epoch 84/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9183
# Epoch 85/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9368
# Epoch 86/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9057
# Epoch 87/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9196
# Epoch 88/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9340
# Epoch 89/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9511
# Epoch 90/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9295
# Epoch 91/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9137
# Epoch 92/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9135
# Epoch 93/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.8798
# Epoch 94/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9061
# Epoch 95/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9056
# Epoch 96/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9258
# Epoch 97/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9220
# Epoch 98/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9352
# Epoch 99/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0193
# Epoch 100/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0899
# Epoch 101/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0803
# Epoch 102/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0820
# Epoch 103/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0708
# Epoch 104/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0590
# Epoch 105/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0783
# Epoch 106/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0389
# Epoch 107/150
# 101/101 [==============================] - 1s 8ms/step - loss: 3.0631
# Epoch 108/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.1017
# Epoch 109/150
# 101/101 [==============================] - 1s 6ms/step - loss: 3.0801
# Epoch 110/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0566
# Epoch 111/150
# 101/101 [==============================] - 1s 6ms/step - loss: 3.0873
# Epoch 112/150
# 101/101 [==============================] - 1s 6ms/step - loss: 3.0969
# Epoch 113/150
# 101/101 [==============================] - 1s 6ms/step - loss: 3.0610
# Epoch 114/150
# 101/101 [==============================] - 1s 6ms/step - loss: 3.0698
# Epoch 115/150
# 101/101 [==============================] - 1s 6ms/step - loss: 3.0676
# Epoch 116/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9767
# Epoch 117/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9566
# Epoch 118/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0047
# Epoch 119/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9499
# Epoch 120/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9642
# Epoch 121/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9639
# Epoch 122/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9954
# Epoch 123/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0668
# Epoch 124/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0909
# Epoch 125/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9857
# Epoch 126/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9508
# Epoch 127/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9585
# Epoch 128/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9706
# Epoch 129/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0160
# Epoch 130/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0382
# Epoch 131/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0552
# Epoch 132/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0511
# Epoch 133/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0681
# Epoch 134/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0896
# Epoch 135/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0310
# Epoch 136/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0451
# Epoch 137/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0842
# Epoch 138/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.1092
# Epoch 139/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.1161
# Epoch 140/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0976
# Epoch 141/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0844
# Epoch 142/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0935
# Epoch 143/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0765
# Epoch 144/150
# 101/101 [==============================] - 1s 7ms/step - loss: 3.0536
# Epoch 145/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9963
# Epoch 146/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9959
# Epoch 147/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9948
# Epoch 148/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9942
# Epoch 149/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9677
# Epoch 150/150
# 101/101 [==============================] - 1s 7ms/step - loss: 2.9833
# Finished training - time elapsed: 1.8656500299771628 min

# %%
names= print_names(model1, gen_amount)
print('First {} generated names:'.format(gen_amount))
for name in names[:gen_amount]:
    print(name)
# Out:
# 10 new names are being generated
# Generated 1
# Generated 2
# Generated 3
# Generated 3
# Generated 4
# Generated 5
# Generated 5
# Generated 6
# Generated 7
# Generated 8
# Generated 8
# Generated 8
# Generated 8
# Generated 8
# Generated 8
# Generated 9
# Generated 10
# First 10 generated names:
# Would?
# You really got me
# Bssh wubflohi lytatosafb any
# F lribltjhlovrd'sysetl
# F lribltjhlovrd'sysetl
# Rssyidvtsryaly'bg buyin
# Pystrolry.elysy
# Pystrolry.elysy
# Wsrosryscictyeyiy thety toy tf
# Thatsrv

# %% [markdown]
# ### Second model

# %%
latent_dim = 64 
dropout_rate = 0.2

# making the NN
model2 = Sequential()

# Add the LSTM layer 
model2.add(LSTM(latent_dim,
               input_shape=(max_sequence_length, num_chars),
               recurrent_dropout=dropout_rate))

# Output layer dense and softmax activation
model2.add(Dense(units=num_chars, activation='softmax'))

# Optmizer in RMS
optimizer = RMSprop(lr=0.01)
model2.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                27648
#
#  dense_1 (Dense)             (None, 43)                2795
#
# =================================================================
# Total params: 30,443
# Trainable params: 30,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time.time()
print('Start training for {} epochs'.format(epochs))
history = model2.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose=1)
end = time.time()
print('Finished training - time elapsed:', (end - start)/60, 'min')
# Out:
# Start training for 150 epochs
# Epoch 1/150
# 101/101 [==============================] - 3s 15ms/step - loss: 2.9857
# Epoch 2/150
# 101/101 [==============================] - 2s 15ms/step - loss: 2.6035
# Epoch 3/150
# 101/101 [==============================] - 2s 15ms/step - loss: 2.4406
# Epoch 4/150
# 101/101 [==============================] - 2s 15ms/step - loss: 2.3343
# Epoch 5/150
# 101/101 [==============================] - 2s 15ms/step - loss: 2.2210
# Epoch 6/150
# 101/101 [==============================] - 2s 15ms/step - loss: 2.1363
# Epoch 7/150
# 101/101 [==============================] - 2s 15ms/step - loss: 2.0511
# Epoch 8/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.9749
# Epoch 9/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.9061
# Epoch 10/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.8336
# Epoch 11/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.7628
# Epoch 12/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.7163
# Epoch 13/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.6510
# Epoch 14/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.6143
# Epoch 15/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.5554
# Epoch 16/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.5225
# Epoch 17/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.5009
# Epoch 18/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.4266
# Epoch 19/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.4151
# Epoch 20/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.3811
# Epoch 21/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.3606
# Epoch 22/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.3131
# Epoch 23/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.2803
# Epoch 24/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.2535
# Epoch 25/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.2319
# Epoch 26/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.2104
# Epoch 27/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.2096
# Epoch 28/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.1942
# Epoch 29/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.1575
# Epoch 30/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.1386
# Epoch 31/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.1157
# Epoch 32/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0871
# Epoch 33/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0937
# Epoch 34/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0787
# Epoch 35/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0570
# Epoch 36/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0564
# Epoch 37/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0471
# Epoch 38/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9976
# Epoch 39/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0155
# Epoch 40/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9770
# Epoch 41/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9627
# Epoch 42/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9682
# Epoch 43/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9420
# Epoch 44/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9337
# Epoch 45/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9171
# Epoch 46/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.9201
# Epoch 47/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.8999
# Epoch 48/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.8847
# Epoch 49/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.8896
# Epoch 50/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.8907
# Epoch 51/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.8802
# Epoch 52/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.8569
# Epoch 53/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.8556
# Epoch 54/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.8303
# Epoch 55/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.8197
# Epoch 56/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.8192
# Epoch 57/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.8047
# Epoch 58/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7950
# Epoch 59/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7914
# Epoch 60/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7609
# Epoch 61/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7883
# Epoch 62/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7610
# Epoch 63/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7606
# Epoch 64/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7477
# Epoch 65/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7570
# Epoch 66/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7365
# Epoch 67/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7395
# Epoch 68/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7279
# Epoch 69/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7308
# Epoch 70/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7214
# Epoch 71/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7307
# Epoch 72/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7186
# Epoch 73/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6794
# Epoch 74/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6991
# Epoch 75/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7067
# Epoch 76/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.7203
# Epoch 77/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6693
# Epoch 78/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6570
# Epoch 79/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6600
# Epoch 80/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6717
# Epoch 81/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6713
# Epoch 82/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6514
# Epoch 83/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.6340
# Epoch 84/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6359
# Epoch 85/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.6532
# Epoch 86/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6476
# Epoch 87/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6249
# Epoch 88/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6138
# Epoch 89/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6217
# Epoch 90/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5932
# Epoch 91/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6247
# Epoch 92/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6074
# Epoch 93/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.6097
# Epoch 94/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.5937
# Epoch 95/150
# 101/101 [==============================] - 2s 16ms/step - loss: 0.6032
# Epoch 96/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5879
# Epoch 97/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5721
# Epoch 98/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5650
# Epoch 99/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5633
# Epoch 100/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5476
# Epoch 101/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5521
# Epoch 102/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5644
# Epoch 103/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5463
# Epoch 104/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5317
# Epoch 105/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5707
# Epoch 106/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5374
# Epoch 107/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5644
# Epoch 108/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5421
# Epoch 109/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5417
# Epoch 110/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5195
# Epoch 111/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5444
# Epoch 112/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5234
# Epoch 113/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5269
# Epoch 114/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5323
# Epoch 115/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5305
# Epoch 116/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5038
# Epoch 117/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5217
# Epoch 118/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5160
# Epoch 119/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5110
# Epoch 120/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5199
# Epoch 121/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4965
# Epoch 122/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4811
# Epoch 123/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4948
# Epoch 124/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4900
# Epoch 125/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4875
# Epoch 126/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.5081
# Epoch 127/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4811
# Epoch 128/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4797
# Epoch 129/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4678
# Epoch 130/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4806
# Epoch 131/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4942
# Epoch 132/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4742
# Epoch 133/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4670
# Epoch 134/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4603
# Epoch 135/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4715
# Epoch 136/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4566
# Epoch 137/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4748
# Epoch 138/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4610
# Epoch 139/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4706
# Epoch 140/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4583
# Epoch 141/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4613
# Epoch 142/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4484
# Epoch 143/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4587
# Epoch 144/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4606
# Epoch 145/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4504
# Epoch 146/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4353
# Epoch 147/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4501
# Epoch 148/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4479
# Epoch 149/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4387
# Epoch 150/150
# 101/101 [==============================] - 2s 15ms/step - loss: 0.4565
# Finished training - time elapsed: 3.8861140966415406 min

# %%
names= print_names(model2, gen_amount)
print('First {} generated names:'.format(gen_amount))
for name in names[:gen_amount]:
    print(name)
# Out:
# 10 new names are being generated
# Generated 1
# Generated 2
# Generated 3
# Generated 4
# Generated 5
# Generated 6
# Generated 7
# Generated 8
# Generated 9
# Generated 10
# First 10 generated names:
# You really got me
# The mon's drman
# Mr. soul
# Mtv:icon medley
# Poor twistead jack built
# House the train hop
# Shoot pera wit the dumb
# Frustration
# Frustration
# Fuel

# %% [markdown]
# ### Third model

# %%
latent_dim = 64 
dropout_rate = 0.2

# making the NN
model3 = Sequential()

# Add the LSTM layer 
model3.add(GRU(latent_dim,
               input_shape=(max_sequence_length, num_chars),
               recurrent_dropout=dropout_rate))

# Output layer dense and softmax activation
model3.add(Dense(units=num_chars, activation='softmax'))

# Optmizer in RMS
optimizer = RMSprop(lr=0.01)
model3.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                20928
#
#  dense_2 (Dense)             (None, 43)                2795
#
# =================================================================
# Total params: 23,723
# Trainable params: 23,723
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time.time()
print('Start training for {} epochs'.format(epochs))
history = model3.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose=1)
end = time.time()
print('Finished training - time elapsed:', (end - start)/60, 'min')
# Out:
# Start training for 150 epochs
# Epoch 1/150
# 101/101 [==============================] - 3s 14ms/step - loss: 2.8295
# Epoch 2/150
# 101/101 [==============================] - 1s 13ms/step - loss: 2.4586
# Epoch 3/150
# 101/101 [==============================] - 1s 13ms/step - loss: 2.3311
# Epoch 4/150
# 101/101 [==============================] - 1s 13ms/step - loss: 2.2266
# Epoch 5/150
# 101/101 [==============================] - 1s 13ms/step - loss: 2.1247
# Epoch 6/150
# 101/101 [==============================] - 1s 13ms/step - loss: 2.0511
# Epoch 7/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.9691
# Epoch 8/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.9143
# Epoch 9/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.8348
# Epoch 10/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.7828
# Epoch 11/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.7557
# Epoch 12/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.6945
# Epoch 13/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.6791
# Epoch 14/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.6281
# Epoch 15/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.6035
# Epoch 16/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.5663
# Epoch 17/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.5642
# Epoch 18/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.5573
# Epoch 19/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.5083
# Epoch 20/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.4816
# Epoch 21/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.4646
# Epoch 22/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.4685
# Epoch 23/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.4580
# Epoch 24/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.4072
# Epoch 25/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.4340
# Epoch 26/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.3860
# Epoch 27/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.3673
# Epoch 28/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.3945
# Epoch 29/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.3389
# Epoch 30/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.3541
# Epoch 31/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.3384
# Epoch 32/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.3243
# Epoch 33/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.3283
# Epoch 34/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.3282
# Epoch 35/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.3024
# Epoch 36/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2727
# Epoch 37/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2772
# Epoch 38/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2491
# Epoch 39/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2648
# Epoch 40/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.2686
# Epoch 41/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2665
# Epoch 42/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.2320
# Epoch 43/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.2443
# Epoch 44/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2164
# Epoch 45/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2212
# Epoch 46/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.2360
# Epoch 47/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1999
# Epoch 48/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1668
# Epoch 49/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1738
# Epoch 50/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1980
# Epoch 51/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1755
# Epoch 52/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1889
# Epoch 53/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1434
# Epoch 54/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1566
# Epoch 55/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1683
# Epoch 56/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1282
# Epoch 57/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1699
# Epoch 58/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1353
# Epoch 59/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1106
# Epoch 60/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1416
# Epoch 61/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1177
# Epoch 62/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1037
# Epoch 63/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1031
# Epoch 64/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1118
# Epoch 65/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1073
# Epoch 66/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0880
# Epoch 67/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1297
# Epoch 68/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.1028
# Epoch 69/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0838
# Epoch 70/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0931
# Epoch 71/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0722
# Epoch 72/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0811
# Epoch 73/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0839
# Epoch 74/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.1009
# Epoch 75/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0691
# Epoch 76/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0473
# Epoch 77/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0545
# Epoch 78/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0726
# Epoch 79/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0462
# Epoch 80/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0317
# Epoch 81/150
# 101/101 [==============================] - 2s 15ms/step - loss: 1.0119
# Epoch 82/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0398
# Epoch 83/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0257
# Epoch 84/150
# 101/101 [==============================] - 1s 15ms/step - loss: 1.0222
# Epoch 85/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0090
# Epoch 86/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0364
# Epoch 87/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0194
# Epoch 88/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0361
# Epoch 89/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0361
# Epoch 90/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0027
# Epoch 91/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0123
# Epoch 92/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0223
# Epoch 93/150
# 101/101 [==============================] - 1s 13ms/step - loss: 1.0107
# Epoch 94/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0052
# Epoch 95/150
# 101/101 [==============================] - 1s 14ms/step - loss: 1.0000
# Epoch 96/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9987
# Epoch 97/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9759
# Epoch 98/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9918
# Epoch 99/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9819
# Epoch 100/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9767
# Epoch 101/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9783
# Epoch 102/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9824
# Epoch 103/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9858
# Epoch 104/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9662
# Epoch 105/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9732
# Epoch 106/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9557
# Epoch 107/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9645
# Epoch 108/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9823
# Epoch 109/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9626
# Epoch 110/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9738
# Epoch 111/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9651
# Epoch 112/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9785
# Epoch 113/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9579
# Epoch 114/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9456
# Epoch 115/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9823
# Epoch 116/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9546
# Epoch 117/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9664
# Epoch 118/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9426
# Epoch 119/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9285
# Epoch 120/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9290
# Epoch 121/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9573
# Epoch 122/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9708
# Epoch 123/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9619
# Epoch 124/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9501
# Epoch 125/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9136
# Epoch 126/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9451
# Epoch 127/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9572
# Epoch 128/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9351
# Epoch 129/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9177
# Epoch 130/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9124
# Epoch 131/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9551
# Epoch 132/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9209
# Epoch 133/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9506
# Epoch 134/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9709
# Epoch 135/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9213
# Epoch 136/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9340
# Epoch 137/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9101
# Epoch 138/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9178
# Epoch 139/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9213
# Epoch 140/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9041
# Epoch 141/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9438
# Epoch 142/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9112
# Epoch 143/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9097
# Epoch 144/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9048
# Epoch 145/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9097
# Epoch 146/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.8964
# Epoch 147/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9010
# Epoch 148/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.8860
# Epoch 149/150
# 101/101 [==============================] - 1s 14ms/step - loss: 0.9007
# Epoch 150/150
# 101/101 [==============================] - 1s 13ms/step - loss: 0.9122
# Finished training - time elapsed: 3.4371578097343445 min

# %%
names= print_names(model3, gen_amount)
print('First {} generated names:'.format(gen_amount))
for name in names[:gen_amount]:
    print(name)
# Out:
# 10 new names are being generated
# Generated 1
# Generated 2
# Generated 2
# Generated 3
# Generated 4
# Generated 5
# Generated 6
# Generated 7
# Generated 8
# Generated 9
# Generated 10
# First 10 generated names:
# You really got me
# The farn her
# Heat far
# Heat far
# Heat far
# Let the real
# Was nowithsnight in the lightning
# No lat me
# No lat me
# Did of the rising

# %% [markdown]
# ### Recommended model
#
# * The model that I recommend is the one with the LSTM layer, which adds more parameters to the training and achieves less loss, being reflected in more consistent song names compared to the other configured networks.
# * However, the model still lacks more robustness to be able to give coherent names.
#
# #### Keyfindings
#
# * An important key is the loss of the model that in 150 epochs gave a total of 0.4565, being significantly lower than the other layers with the same hyperparameters.
#
# * The number of trainable parameters in the LSTM layer is 30,443, being greater than the other configurations, making a significant change.

# %% [markdown]
# ### Next Steps
#
# * In the following steps I would like to add an embedding layer and see how the model performs
# * I would also like to connect more recurring layers or save the weights of a training with another data set and then train a layer to connect the letters and form the song
# * We can add more epochs to see if the loss decreases or train another larger data set to increase the number of sequences with which the model works
